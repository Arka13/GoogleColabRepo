# %% [markdown]
# <a href="https://colab.research.google.com/github/Arka13/GoogleColabRepo/blob/main/First_Try_FromColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python

# %%
a = 2
b = 3

# %% [markdown]
# ##Sum

# %%
c = a+b
print(c)
# Out:
# 5

# %% [markdown]
# ##Product

# %%
d = a*b
print(d)
# Out:
# 6

# %%
x = 1 + 3 * 4 / 12 - 6
x
# Out:
# -4.0

# %%
3 ** 4 // 5 % 3
# Out:
# 1

# %%
a = 'abc'
user_input = input('Please input a number greater than 100: ')

a += user_input
print(a)
# Out:
# Please input a number greater than 100: 123
# abc123
